# %% [markdown]
# # t-sne 觀察 : 流形還原

# %% [markdown]
# # [作業目標]
# - 試著模仿範例寫法, 觀察 S 形使用 t-SNE , 在不同困惑度 (perplexity) 下的流形還原效果

# %% [markdown]
# # [作業重點]
# - 使用 S 形資料集, 觀察 t-sne 在困惑度 (perplexity) 有所不同時, 流形還原的效果如何變化 (In[4], Out[4])
# - Hint : ax.scatter(Y[red, 0], Y[red, 1], c="r") 與 ax.scatter(Y[green, 0], Y[green, 1], c="g") 兩行改一行 ax.scatter(Y[:, 0], Y[:, 1], c=color)

# %%
# 載入套件
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets
from time import time

# %%
# 設定模型與繪圖參數
n_samples = 300
n_components = 2
(fig, subplots) = plt.subplots(2, 5, figsize=(15, 6))
perplexities = [4, 6, 9, 14, 21, 30, 45, 66, 100]

# 設定S曲線資料點
X, color =  datasets.make_s_curve(n_samples, random_state=0)

# %%
# 繪製資料原圖
ax = subplots[0][0]
ax.set_title("Original")
ax.scatter(X[:, 0], X[:, 2], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %% [markdown]
# # 作業
# * 將原始資料集換為S型圖, 觀察不同 perplexity 下的流形還原結果

# %%
n_samples = 300
n_components = 2
perplexities = [4, 6, 9, 14, 21, 30, 45, 66, 100]

# 設定S曲線資料點
i  = 1
num = round((len(perplexities)+ 1) / 2 , 0)
X, y = datasets.make_s_curve(n_samples, random_state=0)
plt.figure(figsize=(15 , 6))
plt.subplot(2 , num , i)
plt.scatter(X[: , 0 ] , X[: , 2] , c=y)
plt.title('origin')

for p in perplexities:
    i += 1
    tsne = manifold.TSNE(n_components=n_components , perplexity=p)
    X_tsne = tsne.fit_transform(X)
    plt.subplot(2 ,num , i)
    plt.scatter(X_tsne[: , 0] , X_tsne[: , 1] , c=y)
    plt.title(f'perplexity={p}')
    
plt.show()
# Out:
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# /Users/eric/.conda/envs/store_project/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
